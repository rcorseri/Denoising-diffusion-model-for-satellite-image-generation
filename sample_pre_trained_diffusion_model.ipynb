# %%
# !python ddpm_train.py --config config/ddpm_sampling_test.json --phase val
# Out:
# export CUDA_VISIBLE_DEVICES=0
# 24-05-23 09:50:48.629 - INFO:   name: ddpm-sampling-remote-sensing-imgs
#   phase: val
#   gpu_ids: [0]
#   path:[
#     log: experiments/ddpm-sampling-remote-sensing-imgs_240523_095048/logs
#     tb_logger: experiments/ddpm-sampling-remote-sensing-imgs_240523_095048/tb_logger
#     results: experiments/ddpm-sampling-remote-sensing-imgs_240523_095048/results
#     checkpoint: experiments/ddpm-sampling-remote-sensing-imgs_240523_095048/checkpoint
#     resume_state: experiments/pre_trained_model/I190000_E97
#     experiments_root: experiments/ddpm-sampling-remote-sensing-imgs_240523_095048
#   ]
#   datasets:[
#     train:[
#       name: LEVIR-WHU-DSIFN
#       dataroot: dataset/Million-AID-LWD
#       resolution: 256
#       batch_size: 8
#       num_workers: 8
#       use_shuffle: True
#       data_len: -1
#     ]
#     val:[
#       name: TEST
#       resolution: 256
#       data_len: 10
#     ]
#   ]
#   model:[
#     which_model_G: sr3
# ...
